# %% [markdown]
# # What should i do
# 1. - Who is have the highest review
# 2. - How much he earns
# 3. - Is his price is high or not
# 4. - Where he is in longitude and latitude
# 5. - Is the people in that longitud and latitude are have a high price and having a good reviews

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import plotly.graph_objects as go 
from plotly.offline import init_notebook_mode, iplot

init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv("listings.csv")

# %%
df = df.drop(df.isna().sum()[((df.isna().sum()/df.shape[0]) > 0.5)].index , axis = 1 )
df = df.dropna()
df = df.reset_index(drop = True)

# %%
df
# Out:
#                       id                                              name  \
# 0                1489424     Welcoming, easygoing, comfy bed, entire level
# 1                2992450                        Luxury 2 bedroom apartment
# 2                3820211         Restored Precinct in Center Sq. w/Parking
# 3                5651579        Large studio apt  by Capital Center & ESP@
# 4                6623339  Center Sq. Loft in Converted Precinct w/ Parking
# ..                   ...                                               ...
# 320  1062527013885315764                  private twin room prime location
# 321  1072781767409521866                               The Bluebird’s Nest
# 322  1075444056381274297                                The Tangerine Door
# 323  1079742757364810916                  Lark St Oasis: Parking & Laundry
# 324  1104977057298366617  Safe, Affordable, Adorable w/ Hot Tub and Coffee
#
#        host_id host_name    neighbourhood   latitude  longitude  \
# ...

# %% [markdown]
# TODO function for plot all top 10 for catigorical cols

# %%
df["host_name"].value_counts()[:10].plot(kind = "bar")
# Out:
# <Axes: xlabel='host_name'>

# %% [markdown]
# the common 10 hosts

# %%
df[df["host_name"].isin(df["host_name"].value_counts()[:10].index)]
# Out:
#                       id                                               name  \
# 2                3820211          Restored Precinct in Center Sq. w/Parking
# 4                6623339   Center Sq. Loft in Converted Precinct w/ Parking
# 10              10768745          Alb hospital area studio bath wifi. (Red)
# 11              11253948  /Fire Place Bungalow\ 1917 SUNY Eagle 6Beds 2B...
# 13              12284708      Well Lit Modern Room, Perfect Location Albany
# ..                   ...                                                ...
# 303  1018299533220989494  Huge house in perfect spot with Hot Tub and Co...
# 304  1018972187574908115                    1 Comfy Bedroom Across the Park
# 306  1020993107237604444   *N E W* Spacious Prime DT 1 Bedroom Apt w Office
# 307  1021011347006185640   *N E W* Modern 1 Bedroom RARE Apt w office space
# 324  1104977057298366617   Safe, Affordable, Adorable w/ Hot Tub and Coffee
#
# ...

# %%
df = df.sort_values("latitude")
df.neighbourhood.nunique()
# Out:
# 15
